# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
#ESQUIZOFRENIA
p1 = pd.read_csv('./esquizofrenia/patient/patient_1.csv',  parse_dates=True, index_col=0)
p2 = pd.read_csv('./esquizofrenia/patient/patient_2.csv',  parse_dates=True, index_col=0)
p3 = pd.read_csv('./esquizofrenia/patient/patient_3.csv',  parse_dates=True, index_col=0)
p4 = pd.read_csv('./esquizofrenia/patient/patient_4.csv',  parse_dates=True, index_col=0)
p5 = pd.read_csv('./esquizofrenia/patient/patient_5.csv',  parse_dates=True, index_col=0)
p6 = pd.read_csv('./esquizofrenia/patient/patient_6.csv',  parse_dates=True, index_col=0)
p7 = pd.read_csv('./esquizofrenia/patient/patient_7.csv',  parse_dates=True, index_col=0)
p8 = pd.read_csv('./esquizofrenia/patient/patient_8.csv',  parse_dates=True, index_col=0)
p9 = pd.read_csv('./esquizofrenia/patient/patient_9.csv',  parse_dates=True, index_col=0)
p10 = pd.read_csv('./esquizofrenia/patient/patient_10.csv',  parse_dates=True, index_col=0)
p11 = pd.read_csv('./esquizofrenia/patient/patient_11.csv',  parse_dates=True, index_col=0)
p12 = pd.read_csv('./esquizofrenia/patient/patient_12.csv',  parse_dates=True, index_col=0)
p13 = pd.read_csv('./esquizofrenia/patient/patient_13.csv',  parse_dates=True, index_col=0)
p14 = pd.read_csv('./esquizofrenia/patient/patient_14.csv',  parse_dates=True, index_col=0)
p15 = pd.read_csv('./esquizofrenia/patient/patient_15.csv',  parse_dates=True, index_col=0)
p16 = pd.read_csv('./esquizofrenia/patient/patient_16.csv',  parse_dates=True, index_col=0)
p17 = pd.read_csv('./esquizofrenia/patient/patient_17.csv',  parse_dates=True, index_col=0)
p18 = pd.read_csv('./esquizofrenia/patient/patient_18.csv',  parse_dates=True, index_col=0)
p19 = pd.read_csv('./esquizofrenia/patient/patient_19.csv',  parse_dates=True, index_col=0)
p20 = pd.read_csv('./esquizofrenia/patient/patient_20.csv',  parse_dates=True, index_col=0)
p21 = pd.read_csv('./esquizofrenia/patient/patient_21.csv',  parse_dates=True, index_col=0)
p22 = pd.read_csv('./esquizofrenia/patient/patient_22.csv',  parse_dates=True, index_col=0)

# %%
#DEPRESION
c1 = pd.read_csv('./depresion/condition/condition_1.csv',  parse_dates=True, index_col=0)
c2 = pd.read_csv('./depresion/condition/condition_2.csv',  parse_dates=True, index_col=0)
c3 = pd.read_csv('./depresion/condition/condition_3.csv',  parse_dates=True, index_col=0)
c4 = pd.read_csv('./depresion/condition/condition_4.csv',  parse_dates=True, index_col=0)
c5 = pd.read_csv('./depresion/condition/condition_5.csv',  parse_dates=True, index_col=0)
c6 = pd.read_csv('./depresion/condition/condition_6.csv',  parse_dates=True, index_col=0)
c7 = pd.read_csv('./depresion/condition/condition_7.csv',  parse_dates=True, index_col=0)
c8 = pd.read_csv('./depresion/condition/condition_8.csv',  parse_dates=True, index_col=0)
c9 = pd.read_csv('./depresion/condition/condition_9.csv',  parse_dates=True, index_col=0)
c10 = pd.read_csv('./depresion/condition/condition_10.csv',  parse_dates=True, index_col=0)
c11 = pd.read_csv('./depresion/condition/condition_11.csv',  parse_dates=True, index_col=0)
c12 = pd.read_csv('./depresion/condition/condition_12.csv',  parse_dates=True, index_col=0)
c13 = pd.read_csv('./depresion/condition/condition_13.csv',  parse_dates=True, index_col=0)
c14 = pd.read_csv('./depresion/condition/condition_14.csv',  parse_dates=True, index_col=0)
c15 = pd.read_csv('./depresion/condition/condition_15.csv',  parse_dates=True, index_col=0)
c16 = pd.read_csv('./depresion/condition/condition_16.csv',  parse_dates=True, index_col=0)
c17 = pd.read_csv('./depresion/condition/condition_17.csv',  parse_dates=True, index_col=0)
c18 = pd.read_csv('./depresion/condition/condition_18.csv',  parse_dates=True, index_col=0)
c19 = pd.read_csv('./depresion/condition/condition_19.csv',  parse_dates=True, index_col=0)
c20 = pd.read_csv('./depresion/condition/condition_20.csv',  parse_dates=True, index_col=0)
c21 = pd.read_csv('./depresion/condition/condition_21.csv',  parse_dates=True, index_col=0)
c22 = pd.read_csv('./depresion/condition/condition_22.csv',  parse_dates=True, index_col=0)
c23 = pd.read_csv('./depresion/condition/condition_23.csv',  parse_dates=True, index_col=0)

# %%
p1
# Out:
#                            date  activity
# timestamp
# 2003-09-02 09:00:00  2003-09-02       665
# 2003-09-02 09:01:00  2003-09-02       166
# 2003-09-02 09:02:00  2003-09-02       116
# 2003-09-02 09:03:00  2003-09-02         0
# 2003-09-02 09:04:00  2003-09-02         0
# ...                         ...       ...
# 2003-09-17 14:21:00  2003-09-17         0
# 2003-09-17 14:22:00  2003-09-17         0
# 2003-09-17 14:23:00  2003-09-17         3
# 2003-09-17 14:24:00  2003-09-17         0
# 2003-09-17 14:25:00  2003-09-17         3
#
# [21926 rows x 2 columns]

# %% [markdown]
# Paciente 1

# %%
horas = p1['activity'].resample('H').mean()
plt.plot(horas.loc['2003-09'].values)
plt.title('Actividad motora del paciente 1')
plt.xlabel('Tiempo (horas)')
plt.ylabel('Unidad motora/hora')
plt.savefig('P1_esq.png')

# %%
horas = p1['activity'].resample('H').mean()
plt.plot(horas.loc['2003-09-11'].values)
plt.title('Día 7 del paciente 1')
plt.xlabel('Tiempo (mins)')
plt.ylabel('Unidad motora/min')
plt.savefig('P1D7_esq.png')

# %% [markdown]
# Paciente 13

# %%
horas = p13['activity'].resample('H').mean()
plt.plot(horas.loc['2003-10'].values)
plt.title('Actividad motora del paciente 13')
plt.xlabel('Tiempo (horas)')
plt.ylabel('Unidad motora/hora')

plt.savefig('P13_esq.png')

# %%
p13
# Out:
#                            date  activity
# timestamp
# 2003-10-14 09:00:00  2003-10-14         2
# 2003-10-14 09:01:00  2003-10-14       146
# 2003-10-14 09:02:00  2003-10-14         0
# 2003-10-14 09:03:00  2003-10-14         0
# 2003-10-14 09:04:00  2003-10-14         0
# ...                         ...       ...
# 2003-10-29 12:29:00  2003-10-29         0
# 2003-10-29 12:30:00  2003-10-29        12
# 2003-10-29 12:31:00  2003-10-29         0
# 2003-10-29 12:32:00  2003-10-29         0
# 2003-10-29 12:33:00  2003-10-29         0
#
# [21874 rows x 2 columns]

# %%
horas = p13['activity'].resample('H').mean()
plt.plot(horas.loc['2003-10-19'].values)
plt.title('Día 5 del paciente 13')
plt.xlabel('Tiempo (mins)')
plt.ylabel('Unidad motora/min')
plt.savefig('P13D5_esq.png')

# %%
#paciente 4 con depresion
horas = c4['activity'].resample('H').mean()
plt.plot(horas.loc['2003-06'].values)
plt.title('Actividad motora del paciente 4')
plt.xlabel('Tiempo (horas)')
plt.ylabel('Unidad motora/hora')
plt.savefig('P4Dep.png')

# %%
c4
# Out:
#                            date  activity
# timestamp
# 2003-06-03 11:59:00  2003-06-03       510
# 2003-06-03 12:00:00  2003-06-03       637
# 2003-06-03 12:01:00  2003-06-03       598
# 2003-06-03 12:02:00  2003-06-03       251
# 2003-06-03 12:03:00  2003-06-03        93
# ...                         ...       ...
# 2003-06-18 11:10:00  2003-06-18         0
# 2003-06-18 11:11:00  2003-06-18         0
# 2003-06-18 11:12:00  2003-06-18         0
# 2003-06-18 11:13:00  2003-06-18         0
# 2003-06-18 11:14:00  2003-06-18         0
#
# [21556 rows x 2 columns]

# %%
horas = c4['activity'].resample('H').mean()
plt.plot(horas.loc['2003-06-16'].values)
plt.title('Día 12 del paciente 4')
plt.xlabel('Tiempo (mins)')
plt.ylabel('Unidad motora/min')
plt.savefig('P4D12.png')
