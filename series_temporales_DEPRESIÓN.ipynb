# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('fast')
 
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler
 
c1 = pd.read_csv('./depresion/condition/condition_1.csv',  parse_dates=True, index_col=0)
c2 = pd.read_csv('./depresion/condition/condition_2.csv',  parse_dates=True, index_col=0)
c3 = pd.read_csv('./depresion/condition/condition_3.csv',  parse_dates=True, index_col=0)
c4 = pd.read_csv('./depresion/condition/condition_4.csv',  parse_dates=True, index_col=0)
c5 = pd.read_csv('./depresion/condition/condition_5.csv',  parse_dates=True, index_col=0)
c6 = pd.read_csv('./depresion/condition/condition_6.csv',  parse_dates=True, index_col=0)
c7 = pd.read_csv('./depresion/condition/condition_7.csv',  parse_dates=True, index_col=0)
c8 = pd.read_csv('./depresion/condition/condition_8.csv',  parse_dates=True, index_col=0)
c9 = pd.read_csv('./depresion/condition/condition_9.csv',  parse_dates=True, index_col=0)
c10 = pd.read_csv('./depresion/condition/condition_10.csv',  parse_dates=True, index_col=0)
c11 = pd.read_csv('./depresion/condition/condition_11.csv',  parse_dates=True, index_col=0)
c12 = pd.read_csv('./depresion/condition/condition_12.csv',  parse_dates=True, index_col=0)
c13 = pd.read_csv('./depresion/condition/condition_13.csv',  parse_dates=True, index_col=0)
c14 = pd.read_csv('./depresion/condition/condition_14.csv',  parse_dates=True, index_col=0)
c15 = pd.read_csv('./depresion/condition/condition_15.csv',  parse_dates=True, index_col=0)
c16 = pd.read_csv('./depresion/condition/condition_16.csv',  parse_dates=True, index_col=0)
c17 = pd.read_csv('./depresion/condition/condition_17.csv',  parse_dates=True, index_col=0)
c18 = pd.read_csv('./depresion/condition/condition_18.csv',  parse_dates=True, index_col=0)
c19 = pd.read_csv('./depresion/condition/condition_19.csv',  parse_dates=True, index_col=0)
c20 = pd.read_csv('./depresion/condition/condition_20.csv',  parse_dates=True, index_col=0)
c21 = pd.read_csv('./depresion/condition/condition_21.csv',  parse_dates=True, index_col=0)
c22 = pd.read_csv('./depresion/condition/condition_22.csv',  parse_dates=True, index_col=0)
c23 = pd.read_csv('./depresion/condition/condition_23.csv',  parse_dates=True, index_col=0)

# %%
c_1 = c1.drop(['date'],axis=1)
c_2 = c2.drop(['date'],axis=1)
c_3 = c3.drop(['date'],axis=1)
c_4 = c4.drop(['date'],axis=1)
c_5 = c5.drop(['date'],axis=1)
c_6 = c6.drop(['date'],axis=1)
c_7 = c7.drop(['date'],axis=1)
c_8 = c8.drop(['date'],axis=1)
c_9 = c9.drop(['date'],axis=1)
c_10 = c10.drop(['date'],axis=1)
c_11 = c11.drop(['date'],axis=1)
c_12 = c12.drop(['date'],axis=1)
c_13 = c13.drop(['date'],axis=1)
c_14 = c14.drop(['date'],axis=1)
c_15 = c15.drop(['date'],axis=1)
c_16 = c16.drop(['date'],axis=1)
c_17 = c17.drop(['date'],axis=1)
c_18 = c18.drop(['date'],axis=1)
c_19 = c19.drop(['date'],axis=1)
c_20 = c20.drop(['date'],axis=1)
c_21 = c21.drop(['date'],axis=1)
c_22 = c22.drop(['date'],axis=1)
c_23 = c23.drop(['date'],axis=1)

# %%
c1
# Out:
#                            date  activity
# timestamp
# 2003-05-07 12:00:00  2003-05-07         0
# 2003-05-07 12:01:00  2003-05-07       143
# 2003-05-07 12:02:00  2003-05-07         0
# 2003-05-07 12:03:00  2003-05-07        20
# 2003-05-07 12:04:00  2003-05-07       166
# ...                         ...       ...
# 2003-05-23 15:19:00  2003-05-23         0
# 2003-05-23 15:20:00  2003-05-23         0
# 2003-05-23 15:21:00  2003-05-23         0
# 2003-05-23 15:22:00  2003-05-23         0
# 2003-05-23 15:23:00  2003-05-23       533
#
# [23244 rows x 2 columns]

# %%
def dias(archivo, color):
    d = archivo.resample('D').mean()
    return plt.plot(d.loc['2003'].values, color)

# %%
def dia(archivo, color):
    d = archivo.resample('D').mean()
    return plt.plot(d.loc['2004'].values, color)

# %%
plt.boxplot(c1.resample('H').mean().loc['2003-05'])
# Out:
# C:\Users\anaji\AppData\Local\Temp\ipykernel_14156\1400703658.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plt.boxplot(c1.resample('H').mean().loc['2003-05'])
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f70c6e1f40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f70c6c95e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f70c6e1c70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f70c6c9ac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f70c6c9d90>],
#  'means': []}

# %%
dias(c_1, 'b') #azul
dias(c_2, 'r') #rojo
dias(c_3, 'k') #negro
dias(c_4, 'g') #verde
dias(c_5, 'c') #cian

# %%
dias(c_6, 'b') #azul
dia(c_7, 'r') #rojo
dia(c_8, 'k') #negro
dia(c_9, 'g') #verde
dia(c_10, 'c') #cian

# %%
c_19
# Out:
#                      activity
# timestamp
# 2002-08-29 14:30:00       249
# 2002-08-29 14:31:00        69
# 2002-08-29 14:32:00       116
# 2002-08-29 14:33:00       258
# 2002-08-29 14:34:00       152
# ...                       ...
# 2002-09-13 08:16:00         0
# 2002-09-13 08:17:00         0
# 2002-09-13 08:18:00         0
# 2002-09-13 08:19:00         0
# 2002-09-13 08:20:00         0
#
# [21231 rows x 1 columns]

# %%
plt.plot((c_11.resample('D').mean()).loc['2004'].values, "blue")
plt.plot((c_12.resample('D').mean()).loc['2005'].values, "red")
plt.plot((c_13.resample('D').mean()).loc['2005'].values, "green")
plt.plot((c_14.resample('D').mean()).loc['2005'].values, "black")
plt.plot((c_15.resample('D').mean()).loc['2005'].values, "yellow")

# %%
c_4
# Out:
#                      activity
# timestamp
# 2003-06-03 11:59:00       510
# 2003-06-03 12:00:00       637
# 2003-06-03 12:01:00       598
# 2003-06-03 12:02:00       251
# 2003-06-03 12:03:00        93
# ...                       ...
# 2003-06-18 11:10:00         0
# 2003-06-18 11:11:00         0
# 2003-06-18 11:12:00         0
# 2003-06-18 11:13:00         0
# 2003-06-18 11:14:00         0
#
# [21556 rows x 1 columns]

# %%
plt.plot((c_4.resample('H').mean()).loc['2003-06'].values)
plt.title('Paciente 4')
plt.xlabel('Horas')
plt.ylabel('Actividad motora')
plt.savefig('P4.png')

# %%
horas = c_4.resample('H').mean()
plt.plot(horas.loc['2003-06-16'].values)

# %%
PASOS=100
# convert series to supervised learning

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = c_1.values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed
# Out:
#        var1(t-100)  var1(t-99)  var1(t-98)  var1(t-97)  var1(t-96)  \
# 100      -1.000000   -0.918888   -1.000000   -0.988656   -0.905842
# 101      -0.918888   -1.000000   -0.988656   -0.905842   -0.909246
# 102      -1.000000   -0.988656   -0.905842   -0.909246   -0.990357
# 103      -0.988656   -0.905842   -0.909246   -0.990357   -0.633579
# 104      -0.905842   -0.909246   -0.990357   -0.633579   -0.445264
# ...            ...         ...         ...         ...         ...
# 23239    -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 23240    -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 23241    -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 23242    -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
# 23243    -1.000000   -1.000000   -1.000000   -1.000000   -1.000000
#
#        var1(t-95)  var1(t-94)  var1(t-93)  var1(t-92)  var1(t-91)  ...  \
# 100     -0.909246   -0.990357   -0.633579   -0.445264   -0.826432  ...
# ...

# %%
# split into train and test sets
values = reframed.values
n_train_days = 19900 - (1914+PASOS)
train = values[:n_train_days, :]
test = values[n_train_days:, :]

# split into input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]

# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))

print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (17886, 1, 100) (17886,) (5258, 1, 100) (5258,)

# %%
model = Sequential() 
model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
model.add(Flatten())
model.add(Dense(units = 1, activation='tanh'))
model.compile(optimizer='Adam',loss='mean_absolute_error',metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1, 100)            10100
#
#  flatten (Flatten)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 1)                 101
#
# ...
# Total params: 10,201
# Trainable params: 10,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(x_train,y_train,epochs=100,validation_data=(x_val,y_val),batch_size=PASOS)

#h = model.fit(x=x_train, y=y_train, verbose=0, epochs=100)
#epochs: número de iteraciones que pasa cada entrenamiento por la red neuronal
# Out:
# Epoch 1/100
# 179/179 [==============================] - 1s 3ms/step - loss: 0.0963 - mse: 0.0391 - val_loss: 0.0557 - val_mse: 0.0334
# Epoch 2/100
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0898 - mse: 0.0332 - val_loss: 0.0557 - val_mse: 0.0333
# Epoch 3/100
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0898 - mse: 0.0332 - val_loss: 0.0556 - val_mse: 0.0332
# Epoch 4/100
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0898 - mse: 0.0332 - val_loss: 0.0556 - val_mse: 0.0330
# Epoch 5/100
# 179/179 [==============================] - 1s 3ms/step - loss: 0.0898 - mse: 0.0332 - val_loss: 0.0555 - val_mse: 0.0327
# Epoch 6/100
# 179/179 [==============================] - 1s 3ms/step - loss: 0.0898 - mse: 0.0331 - val_loss: 0.0555 - val_mse: 0.0322
# Epoch 7/100
# 179/179 [==============================] - 1s 3ms/step - loss: 0.0875 - mse: 0.0308 - val_loss: 0.0640 - val_mse: 0.0262
# Epoch 8/100
# ...

# %%
#model.evaluate(x_train,y_train)

# %%
results=model.predict(x_val)

plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')


plt.title('validate')

plt.show()
# Out:
# 165/165 [==============================] - 0s 1ms/step

# %% [markdown]
# ##

# %%
ultimosDias = c_4['2003-06-16']
len(ultimosDias)
# Out:
# C:\Users\anaji\AppData\Local\Temp\ipykernel_14156\4212379799.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   ultimosDias = c_4['2003-06-16']
# 1440

# %%
values = ultimosDias.values
values = values.astype('float32')
# normalize features
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.drop(reframed.columns[[100]], axis=1, inplace=True)
reframed
# Out:
#       var1(t-100)  var1(t-99)  var1(t-98)  var1(t-97)  var1(t-96)  var1(t-95)  \
# 100     -0.944430   -0.918703   -0.926936   -0.890404   -0.964497   -0.956779
# 101     -0.918703   -0.926936   -0.890404   -0.964497   -0.956779   -0.947003
# 102     -0.926936   -0.890404   -0.964497   -0.956779   -0.947003   -0.942372
# 103     -0.890404   -0.964497   -0.956779   -0.947003   -0.942372   -0.964497
# 104     -0.964497   -0.956779   -0.947003   -0.942372   -0.964497   -0.947003
# ...           ...         ...         ...         ...         ...         ...
# 1435    -0.843067   -0.910471   -0.897607   -0.940314   -0.987651   -0.900695
# 1436    -0.910471   -0.897607   -0.940314   -0.987651   -0.900695   -0.776692
# 1437    -0.897607   -0.940314   -0.987651   -0.900695   -0.776692   -0.783381
# 1438    -0.940314   -0.987651   -0.900695   -0.776692   -0.783381   -0.258040
# 1439    -0.987651   -0.900695   -0.776692   -0.783381   -0.258040   -0.564188
#
# ...

# %%
values = reframed.values
x_test = values[99:, :]
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
x_test
# Out:
# array([[[-0.9984564 , -0.9768459 , -0.942372  , ..., -1.        ,
#          -1.        , -1.        ]],
#
#        [[-0.9768459 , -0.942372  , -0.992282  , ..., -1.        ,
#          -1.        , -1.        ]],
#
#        [[-0.942372  , -0.992282  , -1.        , ..., -1.        ,
#          -1.        , -1.        ]],
#
#        ...,
#
#        [[-0.8976074 , -0.9403139 , -0.98765117, ..., -0.32441473,
#          -0.10573703, -0.13352197]],
#
#        [[-0.9403139 , -0.98765117, -0.9006946 , ..., -0.10573703,
#          -0.13352197, -0.73758686]],
#
#        [[-0.98765117, -0.9006946 , -0.77669156, ..., -0.13352197,
#          -0.73758686, -0.8667353 ]]], dtype=float32)

# %%
def agregarNuevoValor(x_test,nuevoValor):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i] = x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1]=nuevoValor
    return x_test
 
results=[]
for i in range(100):
    parcial=model.predict(x_test)
    results.append(parcial[0])
    print(x_test)
    x_test=agregarNuevoValor(x_test,parcial[0])
# Out:
# 39/39 [==============================] - 0s 1ms/step
# [[[-0.9984564  -0.9768459  -0.942372   ... -1.         -1.
#    -1.        ]]
#
#  [[-0.9768459  -0.942372   -0.992282   ... -1.         -1.
#    -1.        ]]
#
#  [[-0.942372   -0.992282   -1.         ... -1.         -1.
#    -1.        ]]
#
#  ...
#
#  [[-0.8976074  -0.9403139  -0.98765117 ... -0.32441473 -0.10573703
#    -0.13352197]]
#
#  [[-0.9403139  -0.98765117 -0.9006946  ... -0.10573703 -0.13352197
#    -0.73758686]]
#
#  [[-0.98765117 -0.9006946  -0.77669156 ... -0.13352197 -0.73758686
#    -0.8667353 ]]]
# 39/39 [==============================] - 0s 1ms/step
# [[[-0.9768459  -0.942372   -0.992282   ... -1.         -1.
#    -0.98611766]]
#
#  [[-0.9768459  -0.942372   -0.992282   ... -1.         -1.
#    -1.        ]]
#
#  [[-0.942372   -0.992282   -1.         ... -1.         -1.
#    -1.        ]]
#
#  ...
#
#  [[-0.8976074  -0.9403139  -0.98765117 ... -0.32441473 -0.10573703
#    -0.13352197]]
#
# ...

# %%
adimen = [x for x in results]    
inverted = scaler.inverse_transform(adimen)
